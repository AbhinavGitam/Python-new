# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavGitam/Python-new/blob/module4/module4_graphs_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 60, 100, 190, 230])
ypoints = np.array([0, 100, 162, 120, 200])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Math", "Phy", "English", "CSEN"])
y = np.array([95, 75, 89, 99])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([25, 25, 25, 25])
a = ["abhi", "vedesh", "abhihith", "puppy"]

plt.pie(y,labels = a)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(160, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 15, 6, 7])

plt.plot(ypoints, marker = 'D')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x)
plt.plot(y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y, color = "red")

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Math", "Phy", "English", "CSEN"])
y = np.array([95, 75, 89, 99])
col = np.array(["red", "black", "blue", "green"])

plt.bar(x,y, color = col)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["index", "middle", "ring", "little"])
y = np.array([30, 90, 30, 20])

plt.plot(x,y, "o:r")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,0,0,1,2,3])
y = np.array([0,30, 40,0, 30, 20])

plt.plot(y, color = "red")
plt.grid()
plt.show()

# %% [markdown]
# ##### Adjusting the width of the bar graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1, color = "cyan")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([25, 35, 35, 25])
a = ["abhi", "vedesh", "abhihith", "puppy"]
b = [0, 0.1, 0, 0]
plt.pie(y,labels = a, explode=b)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([90, 150, 120])
a = ["Laptop", "Desktop", "monitor"]
b = [0.0, 0.1, 0.0]
color = ["red", "blue", "white"]
plt.pie(y, labels = a, explode = b)
plt.show()

# %%
import matplotlib.pyplot as plt

fblabels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
fbfrac = [15, 30, 45, 10]
fbcolor = ["blue", "green", "red", "orange"]


fig, ax = plt.subplots()
patches, texts, autotexts  = ax.pie(fbfrac, labels = fblabels, autopct='%1.1f%%',pctdistance=0.8,startangle=90,colors=fbcolor)
[text.set_color('red') for text in texts]
texts[0].set_color('blue')
[autotext.set_color('white') for autotext in autotexts]

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([160, 110, 90])
c = ["red", "blue", "purple"]
d = ["laptop", "desktop", "monitor"]
b = [0.0, 0.1, 0.0]
plt.pie(x, colors = c, labels = d, explode = b)
plt.legend(title = "buddies")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,0,0,1,2,3])
y = np.array([0,30, 40,0, 30, 20])

plt.plot(y, color = "red")
plt.grid()
plt.show()
plt.pie(y)
plt.title("Abhinav", color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Maths", "Physics", "Chemistry"])
ypoints = np.array([25, 30, 27])

plt.plot(xpoints, ypoints, marker = "^", mec = "yellow", mfc = "blue", color = "cyan")

plt.show()
