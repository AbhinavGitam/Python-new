# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavGitam/Python-new/blob/module2/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # String

# %%
name = 'Abhinav'
print(name)
print(type(name))
print(name[0])
# Out:
# Abhinav
# <class 'str'>
# A

# %%
a = 'Hello Abhinav'
print(a)
print(type(a))
print(len(a))
# Out:
# Hello Abhinav
# <class 'str'>
# 13

# %%
a = 'RRR movie has been released'
print('RRR' in a)
# Out:
# True

# %%
a = 'RRR movie has been released'
print(a[0:4])
# Out:
# RRR

# %%
a = 'RRR movie has been released'
print(a.upper())
print(a.lower())
# Out:
# RRR MOVIE HAS BEEN RELEASED
# rrr movie has been released

# %% [markdown]
# #### Remove White spaces

# %%
a = '    RRR movie has been released   '
print(a.strip())
print(a)
# Out:
# RRR movie has been released
#     RRR movie has been released

# %% [markdown]
# #### Replace

# %%
a = 'RRR will release in ott this april'
print(a.replace("RRR", "Radhe Shyam"))
# Out:
# Radhe Shyam will release in ott this april

# %% [markdown]
# #### Split

# %%
a = 'RRR will release in ott this april'
print(a.split())

print(" ")

a = 'RRR will release in ott, this april'
print(a.split(','))
# Out:
# ['RRR', 'will', 'release', 'in', 'ott', 'this', 'april']
#
# ['RRR will release in ott', ' this april']

# %% [markdown]
# #### Concatenation

# %%
a = "123"
b = "Vizag"
c = a + ' ' + b
print(c)

a = "Hello"
b = "Vizag"
c = a + " " + b
print(c)
# Out:
# 123 Vizag
# Hello Vizag

# %%
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod
tempor,
incididunt ut labore e,
dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod
# tempor,
# incididunt ut labore e,
# dolore magna aliqua.

# %% [markdown]
# #### Format Strings

# %%
quantity = 3
itemno = "puppy"
price = 4999
myorder = "I want {} pieces of item {} for {} dollars each."
print(myorder.format(quantity, itemno, price))
print('the total amount is', quantity*price)
# Out:
# I want 3 pieces of item puppy for 4999 dollars each.
# the total amount is 14997

# %%
quantity = 3
itemno = "puppy"
price = 4999
myorder = "I want {} pieces of item {} for {} dollars each."
print(myorder.format(quantity, itemno, price))
amount = 'you need to pay a total of {0} for your order'
print(amount.format(quantity*price))
# Out:
# I want 3 pieces of item puppy for 4999 dollars each.
# you need to pay a total of 14997 for your order

# %%
age = input('Enter Your Age')
txt = "My name is Abhinav, and I am {} years old"
print(txt.format(age))
# Out:
# Enter Your Age17
# My name is Abhinav, and I am 17 years old

# %%
a = int(input('Enter Maths Marks'))
b = int(input('Enter CSE Marks'))
c = int(input('Enter Chemistry Marks'))
d = int(input('Enter BEEE Marks'))

print(' ')

marks = ('Maths Marks are {}\n' 'CSE Marks are {}\n' 'Chemistry Marks are {}\n' 'BEEE Marks are {}')
print(marks.format(a,b,c,d))
total = "The total marks are {}"
print(total.format(a+b+c+d))
# Out:
# Enter Maths Marks98
# Enter CSE Marks98
# Enter Chemistry Marks56
# Enter BEEE Marks48
#
# Maths Marks are 98
# CSE Marks are 98
# Chemistry Marks are 56
# BEEE Marks are 48
# The total marks are 300

# %% [markdown]
# #### capitalise

# %%
a = "abhinav"
b = a.capitalize()
print(b)
# Out:
# Abhinav
